# %% [markdown]
# # 🧠 Advanced Python Recap — Student Exercises Notebook
# This notebook contains **tasks only** — students must write all code themselves.

# %% [markdown]
# ## 1. Variables & Basic Types — Task
# **Task:** Create variables and print them.

# %%
Name="Esraa"
num=205938
#print
print("name is:", Name, " and num is: ", num)
# Out:
# name is: Esraa  and num is:  205938

# %% [markdown]
# ## 2. Control Flow — Task
# Write if/for/while logic.

# %%
for i in range(10):
    if(i%2==0):
        print(i, " is even num")
    else:
        print(i, " is odd num")

i=0
while(i<=10):
    if(i%2==0):
        print(i, " is even num")
    else:
        print(i, " is odd num")
    i+=1
# Out:
# 0  is even num
# 1  is odd num
# 2  is even num
# 3  is odd num
# 4  is even num
# 5  is odd num
# 6  is even num
# 7  is odd num
# 8  is even num
# 9  is odd num
# 0  is even num
# 1  is odd num
# 2  is even num
# 3  is odd num
# 4  is even num
# 5  is odd num
# 6  is even num
# 7  is odd num
# 8  is even num
# 9  is odd num
# 10  is even num

# %% [markdown]
# ## 3. Functions — Task
# Write a welcome() function.

# %%
def welcome(name):
    print("welcome ", name)

welcome("Esraa")
# Out:
# welcome  Esraa

# %% [markdown]
# ## 4. Data Structures — Task
# Create list, dict, set.

# %%
l=[1,2,3,4,5,6, "esraa"]
dic={"apple":"friut", "cat":"animal"}
se={1,2,3,4,5}  #unique elements

# %% [markdown]
# ## 5. List Comprehensions — Task
# Squares + even squares.

# %%
squares=[i**2 for i in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# ## 6. File Handling — Task
# Create, write, read a file.

# %%
from pathlib import Path

path = Path('data.txt')
path.write_text('Hello python')

with path.open('r') as file:
    for line in file:
        print(line.strip())
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\esraa\AppData\Local\Temp\ipykernel_22560\4176713194.py:4: SyntaxWarning: invalid escape sequence '\d'
#   file=open("Gen-AI-course-assignments\data.txt", 'w')
# C:\Users\esraa\AppData\Local\Temp\ipykernel_22560\4176713194.py:8: SyntaxWarning: invalid escape sequence '\D'
#   file=open("E:\DEPI round5 tasks\Gen-AI-course-assignments\data.txt", 'r')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 4
#       1 with open("data.txt", 'x') as file:
#       2     pass
#       3
# ----> 4 file=open("Gen-AI-course-assignments\data.txt", 'w')
#       5 file.write("Hello python")
#       6 file.close()
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Gen-AI-course-assignments\\data.txt'

# %% [markdown]
# ## 7. Error Handling — Task
# Try/except.

# %%
try: 
    i=5/0
    print(i)
except:
    print("error")
# Out:
# error

# %% [markdown]
# ## 8. OOP — Task
# Create a Student class.

# %%
class student:
    def __init__(self, age, name):
        self.name=name
        self.age=age
    def print_data(self):
        print("name", self.name, " age", self.age)

s1=student(20, "esraa")
s1.print_data()
# Out:
# name esraa  age 20

# %% [markdown]
# ## 9. Inheritance — Task
# Create GraduateStudent.

# %%
class graduate_student(student):
    def __init__(self, age, name, grad_flag):
        super().__init__( age, name)
        self.grad_flag=grad_flag
    def print_data(self):
        print("name", self.name, " age", self.age, "grad flag: ",self.grad_flag)
        
s2=graduate_student(24,"esraa", True)
s2.print_data()
# Out:
# name esraa  age 24 grad flag:  True

# %% [markdown]
# ## 10. Decorators — Task
# Logger decorator.

# %%
def log_decorator(func):
    def wrapper(*args, **kwargs):
        print(f"calling {func.__name__}")
        result=func(*args, **kwargs)
        print(f"{func.__name__} finished")
    return wrapper

@log_decorator
def greet(name):
    print("hello ", name)

greet("Alice")
# Out:
# calling greet
# hello  Alice
# greet finished

# %% [markdown]
# ## 11. Generators — Task
# Countdown generator.

# %%
def countdown(n):
    while n>0:
        yield n
        n-=1

for num in countdown(5):
    print(num)
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ## 12. Lambda, Map, Filter, Reduce — Task
# Work with numbers list.

# %%
list1=[1,2,3,4,5]
square=lambda x:x**2
print(square(5))
squares=list(map(lambda x:x**2,list1))
print(squares)
evens=list(filter(lambda x: x%2==0, list1))
print(evens)
from functools import reduce
# Out:
# 25
# [1, 4, 9, 16, 25]
# [2, 4]

# %% [markdown]
# ## 13. Advanced Practice
# - Max/min/avg function
# - Agent class
# - Generator divisible by 3
